# %%
import pandas as pd

# %%
data_m = pd.read_csv('ratings.csv')
data_m.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
dfm = data_m[(data_m['rating'] == 5.0) & data_m[['movieId','rating']].groupby(['movieId'])['rating'].count().nlargest(1)]
dfm.head()
# Out:
#      userId  movieId  rating  timestamp
# 356       4      919     5.0  945079521

# %%
dfp = pd.read_csv('power.csv')
dfp.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
df = dfp[(dfp['category'].isin(['4', '12', '21'])) & (dfp['quantity'] >= 0) & (dfp['year'].isin(['2005', '2006', '2007', '2008', '2009', '2010'])) & (dfp['country'].isin(['Latvia', 'Lithuania', 'Estonia']))]
total_quantity = df['quantity'].sum()
print(total_quantity)
# Out:
# 240580.0

# %%
pd.read_html('https://fortrader.org/quotes')[:5]
# Out:
# [                           Название     Цена  Изменение  Изменение(%)  \
#  0  EURRUB Курс евро к рублю сегодня  79.0683     0.4011        0.5099
#  1       USDRUB Курс рубля к доллару  70.4785     0.4673        0.6675
#
#     Обновлено
#  0        NaN
#  1        NaN  ,
#                             Название    Цена  Изменение  Изменение(%)  \
#  0  Нефть (BRENT) Курс нефти сегодня  41.350      -0.50        -1.190
#  1   Нефть (WTI) Цены на нефть (WTI)  39.150      -0.40        -1.010
#  2          Сахар котировки на сахар  12.630      11.36       894.490
#  3                   Газ Цена на газ   1.696      -0.02        -1.166
#
#     Обновлено
#  0        NaN
#  1        NaN
#  2        NaN
#  3        NaN  ,
#                        Название       Цена  Изменение  Изменение(%)  Обновлено
#  0      Серебро Цена на серебро    17.8300    -0.0270       -0.1510        NaN
#  1    Палладий Цена на Палладий  1907.8000   -12.2000       -0.6400        NaN
# ...
