# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашняя работа №4

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
import ssl
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
url='http://yustiks.ru/dataset/housing.csv'
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(url,  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %% [markdown]
# **Логнормальное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['CRIM']
ax = sns.distplot(x)
plt.title('Частотный график уровня преступности')
plt.xlabel('Уровень преступности')
plt.show()

# %% [markdown]
# **Логнормальное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['ZN']
ax = sns.distplot(x)
plt.title('Частотный график пропорций резидентской земли')
plt.xlabel('Пропорция резидентской земли')
plt.show()

# %% [markdown]
# **Многовершинное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['INDUS']
ax = sns.distplot(x)
plt.title('Частотный график нерозничного бизнеса')
plt.xlabel('Пропорция нерозничного бизнеса')
plt.show()

# %% [markdown]
# **Распределение Бернулли:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['CHAS']
ax = sns.distplot(x)
plt.title('Частотный график близости к реке')
plt.xlabel('Близость к реке')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-aa2c30ecfe05> in <module>
#       4 sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
#       5 x = data['CHAS']
# ----> 6 ax = sns.distplot(x)
#       7 plt.title('Частотный график уровня преступности')
#       8 plt.xlabel('Уровень преступности')
#
# ...

# %% [markdown]
# **Нормальное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['NOX']
ax = sns.distplot(x)
plt.title('Частотный график содержания вредных веществ в воздухе')
plt.xlabel('Содержание вредных веществ в воздухе')
plt.show()

# %% [markdown]
# **Распределение Стьюдента:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['RM']
ax = sns.distplot(x)
plt.title('Частотный график количества комнат в жилых помещениях')
plt.xlabel('Количество комнат в жилых помещениях')
plt.show()

# %% [markdown]
# **Нормальное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['AGE']
ax = sns.distplot(x)
plt.title('Частотный график жилья до 1940 года')
plt.xlabel('Жилье до 1940 года')
plt.show()

# %% [markdown]
# **Нормальное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['DIS']
ax = sns.distplot(x)
plt.title('Частотный график расстояния до 5 центров занятости')
plt.xlabel('Расстояние до 5 центров занятости')
plt.show()

# %% [markdown]
# **Многовершинное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['RAD']
ax = sns.distplot(x)
plt.title('Частотный график расстояния до трассы')
plt.xlabel('Расстояние до трассы')
plt.show()

# %% [markdown]
# **Многовершинное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['TAX']
ax = sns.distplot(x)
plt.title('Частотный график налогов')
plt.xlabel('Налоги')
plt.show()

# %% [markdown]
# **Нормальное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['PTRATIO']
ax = sns.distplot(x)
plt.title('Частотный график соотношения учителей к количеству учеников')
plt.xlabel('Соотношение учителей к количеству учеников')
plt.show()

# %% [markdown]
# **Распределение Стьюдента:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['B']
ax = sns.distplot(x)
plt.title('Частотный график соотношения афроамериканцев')
plt.xlabel('Соотношение афроамериканцев')
plt.show()

# %% [markdown]
# **Нормальное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['MEDV']
ax = sns.distplot(x)
plt.title('Частотный график средней стоимости жилья')
plt.xlabel('Средняя стоимость жилья')
plt.show()

# %% [markdown]
# **Нормальное распределение:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np

sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = data['LSTAT']
ax = sns.distplot(x)
plt.title('Частотный график показания низкого социального статуса')
plt.xlabel('Соотношение низкого социального статуа')
plt.show()

# %% [markdown]
# Построить матрицу корреляций для данной таблицы и выбрать максимально коррелирующий атрибут (несколько атрибутов) с ценой на дома (MEDV атрибут).

# %% [markdown]
# **Согласно матрице корреляций ниже, на цену дома больше всего влияют два фактора:**
#
# 1. Количество комнат - чем больше, чем выше стоимость, прямая корреляция
# 2. Низский социальный статус - чем ниже статус, тем дешевле жилье, обратная корреляция

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(),ax=ax,annot=True,linewidths=0.2,fmt='.2f',cmap='RdYlGn')
plt.show()

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %%
price = data['MEDV']
level = data['LSTAT']

price = np.array(price).reshape(-1,1)
level = np.array(level).reshape(-1,1)

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    price,
    level,
    test_size = 0.2
)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted_y = model.predict(X_test)

# %%
print(mean_squared_error(predicted_y, y_test))
print(mean_absolute_error(predicted_y, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-c0a8aa93c819> in <module>
# ----> 1 print(mean_squared_error(predicted_y, y_test))
#       2 print(mean_absolute_error(predicted_y, y_test))
#
# NameError: name 'mean_squared_error' is not defined

# %%
plt.xlabel('price')
plt.ylabel('level')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(-50, 200, 100)
# Посчитаем предсказанные значения
# y = kx + b
# k = model.coef_
# b = model.intercept_
y = model.coef_*x + model.intercept_
y = np.transpose(y)
plt.plot(x,y)
plt.plot(X_train, y_train, 'r.')
plt.plot(X_test, y_test, 'go')
plt.xlim(0,100)
plt.ylim(0,100)
plt.legend(['Прямая линейной регрессии', 'Тренировочные данные', 'Тестовые данные'])
plt.show()

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data_hap=pd.read_csv(url)
data_hap.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop).

# %%
data_hap.loc[:, ['Country (region)', 'Freedom', 'Ladder', 'SD of Ladder', 'Positive affect', 'Negative affect', 'Social support', 'Corruption', 'Generosity', 'Log of GDP\nper capita', 'Healthy life\nexpectancy']].isnull().sum()
# Out:
# Country (region)            0
# Freedom                     1
# Ladder                      0
# SD of Ladder                0
# Positive affect             1
# Negative affect             1
# Social support              1
# Corruption                  8
# Generosity                  1
# Log of GDP\nper capita      4
# Healthy life\nexpectancy    6
# dtype: int64

# %%
data_hap[['Country (region)', 'Freedom', 'Ladder', 'SD of Ladder', 'Positive affect', 'Negative affect', 'Social support', 'Corruption', 'Generosity', 'Log of GDP\nper capita', 'Healthy life\nexpectancy']].cov()
# Out:
#                               Freedom       Ladder  SD of Ladder  \
# Freedom                   2015.000000  1108.090909    512.363636
# Ladder                    1108.090909  2041.000000   1100.838710
# SD of Ladder               512.363636  1100.838710   2041.000000
# Positive affect           1373.766234   995.928571    173.694805
# Negative affect            866.935065  1061.207792   1259.805195
# Social support             904.538961  1657.428571   1219.519481
# Corruption                 736.268707   370.874150    506.897959
# Generosity                 987.331169  1008.948052    797.779221
# Log of GDP\nper capita     800.926667  1615.000000   1254.526490
# Healthy life\nexpectancy   821.386087  1613.369128   1208.026846
#
#                           Positive affect  Negative affect  Social support  \
# Freedom                       1373.766234       866.935065      904.538961
# Ladder                         995.928571      1061.207792     1657.428571
# ...

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %%
data_hap['Country (region)'].count()
# Out:
# 156

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %% [markdown]
# **Мы видим, что в странах с высоким ВВП и высоким уровнем медицинской помощи населению, жители больше довольны жизнью. Также на уровень удовлетворенности влияет степень свободы в стране и социальная поддержка граждан**

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data_hap.corr(),ax=ax,annot=True,linewidths=0.2,fmt='.2f',cmap='magma')
plt.show()

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %% [markdown]
# **Получилось равномерное непрерывное распределение. Если увеличить количество подбрасываний, то картинка будет нагляднее:**

# %%
import pylab
import numpy as np

# Количество испытаний
trials = 10

# Массив значений
values = numpy.random.randint(1, 7, size=trials)
pylab.hist(values, bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5], edgecolor='white')

pylab.xlabel('Значение')
pylab.ylabel('Количества раз')
pylab.title('Подбрасывание кубика ' + str(trials) + ' раз')
pylab.show()

# %% [markdown]
# Смоделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему?

# %% [markdown]
# **Сумма выборок благодаря закону больших чисел стала нормальным распределением:**

# %%
import pylab
import numpy as np

# Количество испытаний
trials = 50000

# Массив значений
values = []
for i in range(trials):
    values.append(np.random.randint(1, 7) + np.random.randint(1, 7))
pylab.hist(values, bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5, 10.5, 11.5, 12.5, 13.5], facecolor='green', edgecolor='white')

pylab.xlabel('Значение')
pylab.ylabel('Количества раз')
pylab.title('Подбрасывание 2x кубиков' + str(trials) + ' раз')
pylab.show()
